# %%
import tweepy
import webbrowser
import time
import requests
import base64
import json
import seaborn as sns
import numpy as np

# %%
consumer_key = "McleIS9RlMtp6HM6a449tvgYd"
consumer_secret_key = "qzZ1vpvfftGOMkCSq0RaJyLKMg9mnJnPQdVF80eLhno4zib3ws"

# %%
callback_uri="oob"

# %%
# Authenticate url
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=VhSBjgAAAAABK3xgAAABdoi3xIA

# %%
#Reformat the keys and encode them
key_secret = '{}:{}'.format(consumer_key, consumer_secret_key).encode('ascii')
#Transform from bytes to bytes that can be printed
b64_encoded_key = base64.b64encode(key_secret)
#Transform from bytes back into Unicode
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)
auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}
auth_data = {
    'grant_type': 'client_credentials'
}
auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)
print(auth_resp.status_code)
access_token = auth_resp.json()['access_token']
# Out:
# 200

# %%
trend_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

trend_params = {
    'id': 20070458,
}

trend_url = 'https://api.twitter.com/1.1/trends/place.json'  
trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)

# %%
trend_resp
# Out:
# <Response [200]>

# %%
tweet_data = trend_resp.json()
print(tweet_data)
# Out:
# [{'trends': [{'name': '#NationalMathematicsDay', 'url': 'http://twitter.com/search?q=%23NationalMathematicsDay', 'promoted_content': None, 'query': '%23NationalMathematicsDay', 'tweet_volume': None}, {'name': '#PanchayatToParliamentBJP', 'url': 'http://twitter.com/search?q=%23PanchayatToParliamentBJP', 'promoted_content': None, 'query': '%23PanchayatToParliamentBJP', 'tweet_volume': 14998}, {'name': '#tuesdaymotivations', 'url': 'http://twitter.com/search?q=%23tuesdaymotivations', 'promoted_content': None, 'query': '%23tuesdaymotivations', 'tweet_volume': None}, {'name': '#SrinivasaRamanujan', 'url': 'http://twitter.com/search?q=%23SrinivasaRamanujan', 'promoted_content': None, 'query': '%23SrinivasaRamanujan', 'tweet_volume': None}, {'name': '#SaveTodayForFuture', 'url': 'http://twitter.com/search?q=%23SaveTodayForFuture', 'promoted_content': None, 'query': '%23SaveTodayForFuture', 'tweet_volume': 14832}, {'name': 'Legion of Merit', 'url': 'http://twitter.com/search?q=%22Legion+of+Merit%22', 'promoted_content': None, 'query': '%22Legion+of+Merit%22', 'tweet_volume': None}, {'name': 'lee sooman', 'url': 'http://twitter.com/search?q=%22lee+sooman%22', 'promoted_content': None, 'query': '%22lee+sooman%22', 'tweet_volume': 20196}, {'name': 'राष्ट्रीय गणित', 'url': 'http://twitter.com/search?q=%22%E0%A4%B0%E0%A4%BE%E0%A4%B
# %%
type(tweet_data)
# Out:
# list

# %%
len(tweet_data)
# Out:
# 1

# %%
for i in range(0,10):
  print(tweet_data[0]['trends'][i])
# Out:
# {'name': '#NationalMathematicsDay', 'url': 'http://twitter.com/search?q=%23NationalMathematicsDay', 'promoted_content': None, 'query': '%23NationalMathematicsDay', 'tweet_volume': None}
# {'name': '#PanchayatToParliamentBJP', 'url': 'http://twitter.com/search?q=%23PanchayatToParliamentBJP', 'promoted_content': None, 'query': '%23PanchayatToParliamentBJP', 'tweet_volume': 14998}
# {'name': '#tuesdaymotivations', 'url': 'http://twitter.com/search?q=%23tuesdaymotivations', 'promoted_content': None, 'query': '%23tuesdaymotivations', 'tweet_volume': None}
# {'name': '#SrinivasaRamanujan', 'url': 'http://twitter.com/search?q=%23SrinivasaRamanujan', 'promoted_content': None, 'query': '%23SrinivasaRamanujan', 'tweet_volume': None}
# {'name': '#SaveTodayForFuture', 'url': 'http://twitter.com/search?q=%23SaveTodayForFuture', 'promoted_content': None, 'query': '%23SaveTodayForFuture', 'tweet_volume': 14832}
# {'name': 'Legion of Merit', 'url': 'http://twitter.com/search?q=%22Legion+of+Merit%22', 'promoted_content': None, 'query': '%22Legion+of+Merit%22', 'tweet_volume': None}
# {'name': 'lee sooman', 'url': 'http://twitter.com/search?q=%22lee+sooman%22', 'promoted_content': None, 'query': '%22lee+sooman%22', 'tweet_volume': 20196}
# {'name': 'राष्ट्रीय गणित', 'url': 'http://twitter.com/search?q=%22%E0%A4%B0%E0%A4%BE%E0%A4%B7%E0%A5%8D%E0%A4%9F%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%AF+%E0%A4%97%E0%A4%A3%E0%A4%BF%E0%A4%A4%22', 'promoted_content': None, 'query': '%22%E0%A4%B0%E0%A4%BE%E0%A4%B7%E0%A5%8D%E0%A4%9F%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%AF+%E0%A4%97%E0%A4%A3%E0%A4%BF%E0%A4%A4%22', 'tweet_volume': None}
# {'name': 'श्रीनिवास रामानुजन', 'url': 'http://twitter.com/search?q=%22%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%A8%E0%A4%BF%E0%A4%B5%E0%A4%BE%E0%A4%B8+%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%BE%E0%A4%A8%E0%A5%81%E0%A4%9C%E0%A4%A8%22', 'promoted_content': None, 'query': '%22%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%A8%E0%A4%BF%E0%A4%B5%E0%A4%BE%E0%A4%B8+%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%BE%E0%A4%A8%E0%A5%81%E0%A4%9C%E0%A4%A8%22', 'tweet_volume': None}
# {'name': 'US President', 'url': 'http://twitter.com/search?q=%22US+President%22', 'promoted_content': None, 'query': '%22US+President%22', 'tweet_volume': 128227}

# %%
print(type(tweet_data[0]))
# Out:
# <class 'dict'>

# %%
for key, value in tweet_data[0].items() :
    print (key)
# Out:
# trends
# as_of
# created_at
# locations

# %%
print(tweet_data[0]['locations'])
# Out:
# [{'name': 'Delhi', 'woeid': 20070458}]

# %%
top_ten_tags=[]
for i in range(0,10):
  top_ten_tags.append(tweet_data[0]['trends'][i]['name'])
print(top_ten_tags)
# Out:
# ['#NationalMathematicsDay', '#PanchayatToParliamentBJP', '#tuesdaymotivations', '#SrinivasaRamanujan', '#SaveTodayForFuture', 'Legion of Merit', 'lee sooman', 'राष्ट्रीय गणित', 'श्रीनिवास रामानुजन', 'US President']

# %%
master_hash=top_ten_tags[0][1:]
print(master_hash)
# Out:
# NationalMathematicsDay

# %%
trend_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}
'''A UTF-8, URL-encoded search query of 500 characters maximum, 
    including operators. Queries may additionally be limited by complexity.'''
trend_params = {
    
    'q': "%23"+master_hash,
}

trend_url = 'https://api.twitter.com/1.1/search/tweets.json'  
trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)

# %%
tweets=trend_resp.json()

# %%
print(tweets)
# Out:
# {'statuses': [{'created_at': 'Tue Dec 22 05:53:20 +0000 2020', 'id': 1341260511493517313, 'id_str': '1341260511493517313', 'text': 'RT @ieeducation_job: On #NationalMathematicsDay, list of #scholarship for students who wish to study math \n\nhttps://t.co/vBDvreKK8O', 'truncated': False, 'entities': {'hashtags': [{'text': 'NationalMathematicsDay', 'indices': [24, 47]}, {'text': 'scholarship', 'indices': [57, 69]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ieeducation_job', 'name': 'IE Education Jobs', 'id': 1067361803573841921, 'id_str': '1067361803573841921', 'indices': [3, 19]}], 'urls': [{'url': 'https://t.co/vBDvreKK8O', 'expanded_url': 'https://indianexpress.com/article/education/on-national-mathematics-day-list-of-scholarship-fellowship-programme-available-for-students-7113906/', 'display_url': 'indianexpress.com/article/educat…', 'indices': [108, 131]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1313426783757189125, 'id_str': '1313426783757189125', 'name': 'Iram habib', 'screen_name': 'Iramhabib8', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 155, 'friends_count': 308, 'listed_count': 0, 'created_at': 'Tue Oct 06 10:32:24 +0000 2020', 'favourites_count': 289, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 379, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1313431575913140224/-aCobnbd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1313431575913140224/-aCobnbd_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Dec 22 05:31:22 +0000 2020', 'id': 1341254986085269505, 'id_str': '1341254986085269505', 'text': 'On #NationalMathematicsDay, list of #scholarship for students who wish to study math \n\nhttps://t.co/vBDvreKK8O', 'truncated': False, 'entities': {'hashtags': [{'text': 'NationalMathematicsDay', 'indices': [3, 26]}, {'text': 'scholarship', 'indices': [36, 48]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/vBDvreKK8O', 'expanded_url': 'https://indianexpress.com/article/education/on-national-mathematics-day-list-of-scholarship-fellowship-programme-available-for-students-7113906/', 'display_url': 'indianexpress.com/article/educat…', 'indices': [87, 110]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1067361803573841921, 'id_str': '1067361803573841921', 'name': 'IE Education Jobs', 'screen_name': 'ieeducation_job', 'location': 'Noida, India', 'description': '', 'url': 'https://t.co/njoyTJGked', 'entities': {'url': {'urls': [{'url': 'https://t.co/njoyTJGked', 'expanded_url': 'http://indianexpress.com', 'display_url': 'indianexpress.com', 'indices': [0, 23]}]}, ' ...

# %%
print(trend_params)
# Out:
# {'q': '%23NationalMathematicsDay'}

# %%
print(type(tweets))
# Out:
# <class 'dict'>

# %%
for key, value in tweets.items() :
    print (key)
# Out:
# statuses
# search_metadata

# %%
tweets['search_metadata']
# Out:
# {'completed_in': 0.077,
#  'max_id': 1341260511493517313,
#  'max_id_str': '1341260511493517313',
#  'next_results': '?max_id=1341260468946690047&q=%2523NationalMathematicsDay&include_entities=1',
#  'query': '%2523NationalMathematicsDay',
#  'refresh_url': '?since_id=1341260511493517313&q=%2523NationalMathematicsDay&include_entities=1',
#  'count': 15,
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
type(tweets['statuses'])
# Out:
# list

# %%
len(tweets['statuses'])
# Out:
# 15

# %%
tweets['statuses'][0]
# Out:
# {'created_at': 'Tue Dec 22 05:53:20 +0000 2020',
#  'id': 1341260511493517313,
#  'id_str': '1341260511493517313',
#  'text': 'RT @ieeducation_job: On #NationalMathematicsDay, list of #scholarship for students who wish to study math \n\nhttps://t.co/vBDvreKK8O',
#  'truncated': False,
#  'entities': {'hashtags': [{'text': 'NationalMathematicsDay',
#     'indices': [24, 47]},
#    {'text': 'scholarship', 'indices': [57, 69]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'ieeducation_job',
#     'name': 'IE Education Jobs',
#     'id': 1067361803573841921,
#     'id_str': '1067361803573841921',
#     'indices': [3, 19]}],
#   'urls': [{'url': 'https://t.co/vBDvreKK8O',
#     'expanded_url': 'https://indianexpress.com/article/education/on-national-mathematics-day-list-of-scholarship-fellowship-programme-available-for-students-7113906/',
#     'display_url': 'indianexpress.com/article/educat…',
#     'indices': [108, 131]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1313426783757189125,
#   'id_str': '1313426783757189125',
#   'name': 'Iram habib',
#   'screen_name': 'Iramhabib8',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 155,
#   'friends_count': 308,
#   'listed_count': 0,
#   'created_at': 'Tue Oct 06 10:32:24 +0000 2020',
#   'favourites_count': 289,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 379,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1313431575913140224/-aCobnbd_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1313431575913140224/-aCobnbd_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Tue Dec 22 05:31:22 +0000 2020',
#   'id': 1341254986085269505,
#   'id_str': '1341254986085269505',
#   'text': 'On #NationalMathematicsDay, list of #scholarship for students who wish to study math \n\nhttps://t.co/vBDvreKK8O',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'NationalMathematicsDay',
#      'indices': [3, 26]},
#     {'text': 'scholarship', 'indices': [36, 48]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/vBDvreKK8O',
#      'expanded_url': 'https://indianexpress.com/article/education/on-national-mathematics-day-list-of-scholarship-fellowship-programme-available-for-students-7113906/',
#      'display_url': 'indianexpress.com/article/educat…',
#      'indices': [87, 110]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1067361803573841921,
#    'id_str': '1067361803573841921',
#    'name': 'IE Education Jobs',
#    'screen_name': 'ieeducation_job',
#    'location': 'Noida, India',
#    'description': '',
#    'url': 'https://t.co/njoyTJGked',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/njoyTJGked',
#        'expanded_url': 'http://indianexpress.com',
#        'display_url': 'indianexpress.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6843,
#    'friends_count': 2,
#    'listed_count': 25,
#    'created_at': 'Tue Nov 27 10:17:39 +0000 2018',
#    'favourites_count': 30,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 16358,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1068414753004036096/YkXCtiuU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068414753004036096/YkXCtiuU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1067361803573841921/1593237469',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 6,
#   'favorite_count': 29,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 6,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %% [markdown]
# CHecking the keys present in dict of a single tweet

# %%
for key, value in tweets['statuses'][0].items() :
    print (key)
# Out:
# created_at
# id
# id_str
# text
# truncated
# entities
# metadata
# source
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# retweeted_status
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# lang

# %% [markdown]
# ## Converting list of dicts to a dataframe
# https://stackoverflow.com/q/20638006/6427607

# %%
df = pd.DataFrame(tweets['statuses'])

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#                         created_at                   id               id_str  \
# 0   Tue Dec 22 05:53:20 +0000 2020  1341260511493517313  1341260511493517313
# 1   Tue Dec 22 05:53:17 +0000 2020  1341260502991695874  1341260502991695874
# 2   Tue Dec 22 05:53:14 +0000 2020  1341260489930715136  1341260489930715136
# 3   Tue Dec 22 05:53:14 +0000 2020  1341260488697470977  1341260488697470977
# 4   Tue Dec 22 05:53:13 +0000 2020  1341260483366539266  1341260483366539266
# 5   Tue Dec 22 05:53:11 +0000 2020  1341260477821669378  1341260477821669378
# 6   Tue Dec 22 05:53:11 +0000 2020  1341260476622065664  1341260476622065664
# 7   Tue Dec 22 05:53:11 +0000 2020  1341260475514818560  1341260475514818560
# 8   Tue Dec 22 05:53:11 +0000 2020  1341260474566918149  1341260474566918149
# 9   Tue Dec 22 05:53:11 +0000 2020  1341260473740664833  1341260473740664833
# 10  Tue Dec 22 05:53:10 +0000 2020  1341260472742518789  1341260472742518789
# 11  Tue Dec 22 05:53:10 +0000 2020  1341260471676981253  1341260471676981253
# 12  Tue Dec 22 05:53:10 +0000 2020  1341260471442178048  1341260471442178048
# 13  Tue Dec 22 05:53:10 +0000 2020  1341260471110750208  1341260471110750208
# 14  Tue Dec 22 05:53:09 +0000 2020  1341260468946690048  1341260468946690048
#
#                                                  text  truncated  \
# 0   RT @ieeducation_job: On #NationalMathematicsDa...      False
# 1   RT @AmitAgarwal: It's #NationalMathematicsDay,...      False
# 2   RT @SadhguruJV: Mathematics did not get invent...      False
# 3   RT @dineshjoshilax: महान गणितज्ञ #SrinivasaRam...      False
# 4   RT @indutiwarijbp: विश्लेषण एवं संख्या सिद्धां...      False
# 5   RT @punia_tanuj: विश्लेषण एवं संख्या सिद्धांत ...      False
# 6   RT @dinesh_ve: An equation means nothing to me...      False
# 7   RT @NTPatel1999: Born on this day in the year ...      False
# 8   RT @DainikBhaskar: इतिहास में आज: अनंत की खोज ...      False
# 9   RT @PANKAJ_RJ46: Shrinivasa Ramanujan made inc...      False
# 10  RT @SadhguruJV: Mathematics did not get invent...      False
# 11  ప్రపంచ ప్రఖ్యాతగాంచిన భారతీయ గణిత శాస్త్రవేత్త...       True
# 12  अनंत की खोज करने वाले महान गणितज्ञ श्रीनिवास र...       True
# 13  RT @PranavKVFC: Nee epo en life kulla vandhiyo...      False
# 14  RT @SadhguruJV: Mathematics did not get invent...      False
#
#                                              entities  \
# 0   {'hashtags': [{'text': 'NationalMathematicsDay...
# 1   {'hashtags': [{'text': 'NationalMathematicsDay...
# 2   {'hashtags': [{'text': 'SadhguruQuotes', 'indi...
# 3   {'hashtags': [{'text': 'SrinivasaRamanujan', '...
# 4   {'hashtags': [], 'symbols': [], 'user_mentions...
# 5   {'hashtags': [], 'symbols': [], 'user_mentions...
# 6   {'hashtags': [], 'symbols': [], 'user_mentions...
# 7   {'hashtags': [], 'symbols': [], 'user_mentions...
# 8   {'hashtags': [], 'symbols': [], 'user_mentions...
# 9   {'hashtags': [], 'symbols': [], 'user_mentions...
# 10  {'hashtags': [{'text': 'SadhguruQuotes', 'indi...
# 11  {'hashtags': [], 'symbols': [], 'user_mentions...
# 12  {'hashtags': [], 'symbols': [], 'user_mentions...
# 13  {'hashtags': [], 'symbols': [], 'user_mentions...
# 14  {'hashtags': [{'text': 'SadhguruQuotes', 'indi...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'hi', 'result_type': 're...
# 4   {'iso_language_code': 'hi', 'result_type': 're...
# 5   {'iso_language_code': 'hi', 'result_type': 're...
# 6   {'iso_language_code': 'en', 'result_type': 're...
# 7   {'iso_language_code': 'en', 'result_type': 're...
# 8   {'iso_language_code': 'hi', 'result_type': 're...
# 9   {'iso_language_code': 'en', 'result_type': 're...
# 10  {'iso_language_code': 'en', 'result_type': 're...
# 11  {'iso_language_code': 'te', 'result_type': 're...
# 12  {'iso_language_code': 'hi', 'result_type': 're...
# 13  {'iso_language_code': 'et', 'result_type': 're...
# 14  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source in_reply_to_status_id  \
# 0   <a href="https://mobile.twitter.com" rel="nofo...                  None
# 1   <a href="http://twitter.com/download/iphone" r...                  None
# 2   <a href="https://mobile.twitter.com" rel="nofo...                  None
# 3   <a href="http://twitter.com/download/android" ...                  None
# 4   <a href="http://twitter.com/download/android" ...                  None
# 5   <a href="https://mobile.twitter.com" rel="nofo...                  None
# 6   <a href="http://twitter.com/download/android" ...                  None
# 7   <a href="http://twitter.com/download/android" ...                  None
# 8   <a href="http://twitter.com/download/android" ...                  None
# 9   <a href="http://twitter.com/download/android" ...                  None
# 10  <a href="http://twitter.com/download/android" ...                  None
# 11  <a href="http://twitter.com/download/android" ...                  None
# 12  <a href="https://mobile.twitter.com" rel="nofo...                  None
# 13  <a href="http://twitter.com/download/android" ...                  None
# 14  <a href="http://twitter.com/download/android" ...                  None
#
#    in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str  \
# 0                       None                None                    None
# 1                       None                None                    None
# 2                       None                None                    None
# 3                       None                None                    None
# 4                       None                None                    None
# 5                       None                None                    None
# 6                       None                None                    None
# 7                       None                None                    None
# 8                       None                None                    None
# 9                       None                None                    None
# 10                      None                None                    None
# 11                      None                None                    None
# 12                      None                None                    None
# 13                      None                None                    None
# 14                      None                None                    None
#
#    in_reply_to_screen_name                                               user  \
# 0                     None  {'id': 1313426783757189125, 'id_str': '1313426...
# 1                     None  {'id': 3276476922, 'id_str': '3276476922', 'na...
# 2                     None  {'id': 1163437429543411713, 'id_str': '1163437...
# 3                     None  {'id': 844852568580796419, 'id_str': '84485256...
# 4                     None  {'id': 1036118700640722944, 'id_str': '1036118...
# 5                     None  {'id': 1321724868870565888, 'id_str': '1321724...
# 6                     None  {'id': 1296848057443573760, 'id_str': '1296848...
# 7                     None  {'id': 838409346547593216, 'id_str': '83840934...
# 8                     None  {'id': 320163570, 'id_str': '320163570', 'name...
# 9                     None  {'id': 1193451099023233025, 'id_str': '1193451...
# 10                    None  {'id': 856114818, 'id_str': '856114818', 'name...
# 11                    None  {'id': 1153918154755588096, 'id_str': '1153918...
# 12                    None  {'id': 2506662439, 'id_str': '2506662439', 'na...
# 13                    None  {'id': 1337284744090828800, 'id_str': '1337284...
# 14                    None  {'id': 4149915859, 'id_str': '4149915859', 'na...
#
#      geo coordinates place contributors  \
# 0   None        None  None         None
# 1   None        None  None         None
# 2   None        None  None         None
# 3   None        None  None         None
# 4   None        None  None         None
# 5   None        None  None         None
# 6   None        None  None         None
# 7   None        None  None         None
# 8   None        None  None         None
# 9   None        None  None         None
# 10  None        None  None         None
# 11  None        None  None         None
# 12  None        None  None         None
# 13  None        None  None         None
# 14  None        None  None         None
#
#                                      retweeted_status  is_quote_status  \
# 0   {'created_at': 'Tue Dec 22 05:31:22 +0000 2020...            False
# 1   {'created_at': 'Tue Dec 22 05:48:20 +0000 2020...            False
# 2   {'created_at': 'Tue Dec 22 02:45:00 +0000 2020...            False
# 3   {'created_at': 'Tue Dec 22 03:34:52 +0000 2020...            False
# 4   {'created_at': 'Tue Dec 22 05:31:22 +0000 2020...            False
# 5   {'created_at': 'Tue Dec 22 02:35:23 +0000 2020...            False
# 6   {'created_at': 'Tue Dec 22 05:07:18 +0000 2020...            False
# 7   {'created_at': 'Mon Dec 21 18:33:59 +0000 2020...            False
# 8   {'created_at': 'Tue Dec 22 03:45:00 +0000 2020...            False
# 9   {'created_at': 'Tue Dec 22 05:53:02 +0000 2020...            False
# 10  {'created_at': 'Tue Dec 22 02:45:00 +0000 2020...            False
# 11                                                NaN            False
# 12                                                NaN            False
# 13  {'created_at': 'Tue Dec 22 03:54:44 +0000 2020...            False
# 14  {'created_at': 'Tue Dec 22 02:45:00 +0000 2020...            False
#
#     retweet_count  favorite_count  favorited  retweeted possibly_sensitive  \
# 0               6               0      False      False              False
# 1               2               0      False      False                NaN
# 2            2554               0      False      False                NaN
# 3               1               0      False      False                NaN
# 4               3               0      False      False                NaN
# 5               9               0      False      False                NaN
# 6               4               0      False      False                NaN
# 7               5               0      False      False                NaN
# 8              23               0      False      False                NaN
# 9               1               0      False      False                NaN
# 10           2554               0      False      False                NaN
# 11              0               0      False      False              False
# 12              1               2      False      False              False
# 13             11               0      False      False                NaN
# 14           2554               0      False      False                NaN
#
#    lang
# 0    en
# 1    en
# 2    en
# 3    hi
# 4    hi
# 5    hi
# 6    en
# 7    en
# 8    hi
# 9    en
# 10   en
# 11   te
# 12   hi
# 13   et
# 14   en

# %%
tweets['statuses'][0]['user']
# Out:
# {'id': 1313426783757189125,
#  'id_str': '1313426783757189125',
#  'name': 'Iram habib',
#  'screen_name': 'Iramhabib8',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 155,
#  'friends_count': 308,
#  'listed_count': 0,
#  'created_at': 'Tue Oct 06 10:32:24 +0000 2020',
#  'favourites_count': 289,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 379,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1313431575913140224/-aCobnbd_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1313431575913140224/-aCobnbd_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None,
#  'translator_type': 'none'}

# %%
tweets['statuses'][0]['entities']
# Out:
# {'hashtags': [{'text': 'NationalMathematicsDay', 'indices': [24, 47]},
#   {'text': 'scholarship', 'indices': [57, 69]}],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'ieeducation_job',
#    'name': 'IE Education Jobs',
#    'id': 1067361803573841921,
#    'id_str': '1067361803573841921',
#    'indices': [3, 19]}],
#  'urls': [{'url': 'https://t.co/vBDvreKK8O',
#    'expanded_url': 'https://indianexpress.com/article/education/on-national-mathematics-day-list-of-scholarship-fellowship-programme-available-for-students-7113906/',
#    'display_url': 'indianexpress.com/article/educat…',
#    'indices': [108, 131]}]}

# %% [markdown]
# # Extracting tweets

# %%
def get_tweets_since(url_given):
    trend_headers = {
        'Authorization': 'Bearer {}'.format(access_token)    
    }
    '''A UTF-8, URL-encoded search query of 500 characters maximum, 
        including operators. Queries may additionally be limited by complexity.'''
    trend_params = {

        'q': "%23"+master_hash,
        'count': 100,
        'min_id':0
    }
    if url_given==-1:
        trend_url = 'https://api.twitter.com/1.1/search/tweets.json'  
        trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)
    else:
        trend_url='https://api.twitter.com/1.1/search/tweets.json'+url_given
        trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)
        

    tweets=trend_resp.json()
    #return tweets['statuses'],tweets['search_metadata']["max_id"]
    return tweets

# %%
tweets_list=[]
give_url=-1
for i in range(0,105):
    tweets_obj=get_tweets_since(give_url)
    #print(type(tweets_obj))
    #print(tweets_obj)
    tmp_list=tweets_obj['statuses']
    #print(now_min_id)
    #now_min_id=tweets_obj['search_metadata']["max_id"]+1
    print('Netx res',tweets_obj['search_metadata']["next_results"])
    give_url=tweets_obj['search_metadata']["next_results"]
    tweets_list.extend(tmp_list)
    print("len of master list now is",len(tweets_list))
    print(tweets_obj['search_metadata']["max_id"])
    print('len of tmp_list is ',len(tmp_list))
    print("id of first tweet in current stint is ",tmp_list[0]['id'])
    #for j in tmp_list:
        #print(j['id'])
   
    print("-------------------------------------------------------------------------------------")
# Out:
# Netx res ?max_id=1341289202781020162&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 100
# 1341289965087379457
# len of tmp_list is  100
# id of first tweet in current stint is  1341289965087379457
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341288596234358784&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 200
# 1341289202781020162
# len of tmp_list is  100
# id of first tweet in current stint is  1341289195898167296
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341287878740029439&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 300
# 1341288596234358784
# len of tmp_list is  100
# id of first tweet in current stint is  1341288593168486401
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341287180103077889&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 400
# 1341287878740029439
# len of tmp_list is  100
# id of first tweet in current stint is  1341287877100019717
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341286541927170048&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 500
# 1341287180103077889
# len of tmp_list is  100
# id of first tweet in current stint is  1341287176697380865
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341285929454071808&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 600
# 1341286541927170048
# len of tmp_list is  100
# id of first tweet in current stint is  1341286538420752384
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341285318238949375&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 700
# 1341285929454071808
# len of tmp_list is  100
# id of first tweet in current stint is  1341285929386790912
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341284711155556351&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 800
# 1341285318238949375
# len of tmp_list is  100
# id of first tweet in current stint is  1341285316527677443
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341284079677784063&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 900
# 1341284711155556351
# len of tmp_list is  100
# id of first tweet in current stint is  1341284705145139202
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341283440965009419&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 1000
# 1341284079677784063
# len of tmp_list is  100
# id of first tweet in current stint is  1341284073918976001
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341245948802912255&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9200
# 1341246274125762559
# len of tmp_list is  100
# id of first tweet in current stint is  1341246273769238529
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341245565904900096&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9300
# 1341245948802912255
# len of tmp_list is  100
# id of first tweet in current stint is  1341245936241012737
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341245136580198400&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9400
# 1341245565904900096
# len of tmp_list is  100
# id of first tweet in current stint is  1341245547034730502
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341244771923156993&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9500
# 1341245136580198400
# len of tmp_list is  100
# id of first tweet in current stint is  1341245128074137600
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341244330774687749&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9600
# 1341244771923156993
# len of tmp_list is  100
# id of first tweet in current stint is  1341244757897404421
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341243917602189311&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9700
# 1341244330774687749
# len of tmp_list is  100
# id of first tweet in current stint is  1341244329608691717
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341243547320610815&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9800
# 1341243917602189311
# len of tmp_list is  100
# id of first tweet in current stint is  1341243914041192448
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341243141240672255&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 9900
# 1341243547320610815
# len of tmp_list is  100
# id of first tweet in current stint is  1341243545621950464
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341242766978809855&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 10000
# 1341243141240672255
# len of tmp_list is  100
# id of first tweet in current stint is  1341243137444904960
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341242394885246975&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 10100
# 1341242766978809855
# len of tmp_list is  100
# id of first tweet in current stint is  1341242763568791552
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341242048213442559&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 10200
# 1341242394885246975
# len of tmp_list is  100
# id of first tweet in current stint is  1341242391966011392
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341241711616434175&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 10300
# 1341242048213442559
# len of tmp_list is  100
# id of first tweet in current stint is  1341242047676600321
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341241366328844287&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 10400
# 1341241711616434175
# len of tmp_list is  100
# id of first tweet in current stint is  1341241709330513920
# -------------------------------------------------------------------------------------
# Netx res ?max_id=1341241078561685503&q=%2523NationalMathematicsDay&count=100&include_entities=1
# len of master list now is 10500
# 1341241366328844287
# len of tmp_list is  100
# id of first tweet in current stint is  1341241355100557313
# -------------------------------------------------------------------------------------

# %%
len(tweets_list)
# Out:
# 100

# %% [markdown]
# url = API_ROOT + 'search/tweets.json'
# params = {
#     'q': '#TrumpCup',
#     'result_type': 'recent',
#     'count':100,
#
#
# }
# resp = requests.get(url, headers=HEADERS, params=params)
# search_data = resp.json()
#
#
# url = API_ROOT + 'search/tweets.json'+    search_data["search_metadata"]["next_results"]
# params = {
#     'q': '#TrumpCup',
#     'result_type': 'recent',
#     'count':100,
#
#
# }
# resp = requests.get(url, headers=HEADERS, params=params)
# search_data = resp.json()
#
# statuses = search_data['statuses']
# len(statuses)

# %% [markdown]
# ## Storing the 105k tweets as JSON

# %%
tweets_dict={
    "tweets_extracted":tweets_list
}

# %%
with open("sample.json", "w") as outfile:  
    json.dump(tweets_dict, outfile,indent=4)

# %% [markdown]
# ## Involving useful columns in a dataframe
# Link describing the field meanings: https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet

# %%
i=0
print(tweets_list[i]["id"])

# The actual UTF-8 text of the status update.
print(tweets_list[i]["text"])

# Name of the user
print(tweets_list[i]["user"]["name"])
print(tweets_list[i]["user"]["followers_count"])
print(tweets_list[i]["user"]["friends_count"])
print(tweets_list[i]['user']["verified"])


#Number of times this Tweet has been retweeted. 
print(tweets_list[i]["retweet_count"])
print(tweets_list[i]["favorite_count"])
print(tweets_list[i]["lang"])

# Entities
print(tweets_list[i]["entities"])
print(tweets_list[i]["entities"]["hashtags"])
print(tweets_list[i]["entities"]["urls"])
#print(tweets_list[i]["entities"]["media"])
# Out:
# 1341289965087379457
# Remembering the Legendary Mathematician, #SrinivasaRamanujan on his birth anniversary, which is also celebrated as… https://t.co/yBFxhF8Iio
# Sujeet Kumar
# 3670
# 340
# True
# 0
# 0
# en
# {'hashtags': [{'text': 'SrinivasaRamanujan', 'indices': [41, 60]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/yBFxhF8Iio', 'expanded_url': 'https://twitter.com/i/web/status/1341289965087379457', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}
# [{'text': 'SrinivasaRamanujan', 'indices': [41, 60]}]
# [{'url': 'https://t.co/yBFxhF8Iio', 'expanded_url': 'https://twitter.com/i/web/status/1341289965087379457', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]

# %% [markdown]
# ## Selecting useful fields

# %%
mod_list=[]
cnt=0
user_id_list=[]
extra_hashtags_list=[]
text_str=""
user_map={}
for a_tweet in tweets_list:
    tmp_d={}
    #tmp_d["id"]=a_tweet["id"]
    tmp_d["user_name"]=a_tweet["user"]["name"]
    tmp_d["num_retweets"]=a_tweet["retweet_count"]
    tmp_d["num_likes"]=a_tweet["favorite_count"]
    tmp_d["lang"]=a_tweet["lang"]
    tmp_d["num_user_followers"]=a_tweet["user"]["followers_count"]
    tmp_d["num_user_friends"]=a_tweet["user"]["friends_count"]
    tmp_d["num_ext_hashtags"]=0
    tmp_d["num_ext_urls"]=0
    tmp_d["num_ext_media"]=0
    tmp_d['text']=a_tweet['text']
    text_str=text_str+"\n\n"+tmp_d['text']
    if a_tweet["user"]["verified"]==True:
        tmp_d["is_verified"]="verified"
    else:
        tmp_d["is_verified"]="not_verified"
        
    if "hashtags" in a_tweet["entities"].keys():
        tmp_d["num_ext_hashtags"]=len(a_tweet["entities"]["hashtags"])
        for x in a_tweet["entities"]["hashtags"]:
            extra_hashtags_list.append(x['text'])
    if "urls" in a_tweet["entities"].keys():
        tmp_d["num_ext_urls"]=len(a_tweet["entities"]["urls"])
    if "media" in a_tweet["entities"].keys():
        tmp_d["num_ext_media"]=len(a_tweet["entities"]["media"]) 
    if "coordinates" in a_tweet.keys() and a_tweet["coordinates"]!=None:
        #print(a_tweet.keys())
        #print(a_tweet["coordinates"]["coordinates"])        
        tmp_d["longitude"]=a_tweet["coordinates"]["coordinates"][0]
        tmp_d["latitude"]=a_tweet["coordinates"]["coordinates"][1]
        cnt+=1
    elif a_tweet["place"]!=None:
        #print(a_tweet["place"]["bounding_box"]["coordinates"][0][0])
        tmp_d["longitude"]=a_tweet["place"]["bounding_box"]["coordinates"][0][0][0]
        tmp_d["latitude"]=a_tweet["place"]["bounding_box"]["coordinates"][0][0][1]
        cnt+=1
    mod_list.append(tmp_d)
    user_id_list.append(a_tweet["user"]["id"])
    user_map[a_tweet["user"]["id"]]=a_tweet["user"]["name"]
    
    #print(tmp_d)
    #break

# %%
print(len(mod_list))
# Out:
# 10500

# %%
print(len(extra_hashtags_list))
# Out:
# 10286

# %%
df = pd.DataFrame(mod_list)

# %%
df
# Out:
#                              user_name  num_retweets  num_likes lang  \
# 0                         Sujeet Kumar             0          0   en
# 1      ज्योति ठाकुर 👉 आओ हिंदी लिखें ✍             0          0   hi
# 2                            R.Dwivedi            47          0   hi
# 3                      🌸 एकता शुक्ला 🌸            14          0   en
# 4                 CHARANJEET SHER GILL             0          0   hi
# ...                                ...           ...        ...  ...
# 10495            Vishwa Samvada Kendra            33          0   en
# 10496          Er. Ami Chand Choudhary            22          0   hi
# 10497                              Sai          3456          0   en
# 10498                 Advanced Academy             0          0   en
# 10499                      Basava Raju          3456          0   en
#
#        num_user_followers  num_user_friends  num_ext_hashtags  num_ext_urls  \
# 0                    3670               340                 1             1
# 1                    7555              5061                 1             0
# 2                    2629              2704                 0             0
# 3                    2950               189                 1             0
# 4                     187              4482                 0             1
# ...                   ...               ...               ...           ...
# 10495                8571               554                 0             0
# 10496                  32                62                 3             0
# 10497                 216               196                 1             0
# 10498                   2                16                 0             1
# 10499                   2                 3                 1             0
#
#        num_ext_media                                               text  \
# 0                  0  Remembering the Legendary Mathematician, #Srin...
# 1                  0  #NationalMathematicsDay.... जीरो दिया मेरे भार...
# 2                  0  RT @Tiwari2941: आर्यभट्ट की परंपरा को आगे बढ़ा...
# 3                  0  RT @Cjacksparrow_5: #NationalMathematicsDay\nM...
# 4                  0  विश्लेषण एवं संख्या सिद्धांत के क्षेत्रों में ...
# ...              ...                                                ...
# 10495              0  RT @UniqueBisht_85: An equation means nothing ...
# 10496              0  RT @djjsakhandgyan: #NationalMathematicsDay \n...
# 10497              0  RT @SadhguruJV: Mathematics did not get invent...
# 10498              0  On the occasion of National Mathematics Day, w...
# 10499              0  RT @SadhguruJV: Mathematics did not get invent...
#
#         is_verified  longitude  latitude
# 0          verified        NaN       NaN
# 1      not_verified        NaN       NaN
# 2      not_verified        NaN       NaN
# 3      not_verified        NaN       NaN
# 4      not_verified        NaN       NaN
# ...             ...        ...       ...
# 10495  not_verified        NaN       NaN
# 10496  not_verified        NaN       NaN
# 10497  not_verified        NaN       NaN
# 10498  not_verified        NaN       NaN
# 10499  not_verified        NaN       NaN
#
# [10500 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['user_name', 'num_retweets', 'num_likes', 'lang', 'num_user_followers',
#        'num_user_friends', 'num_ext_hashtags', 'num_ext_urls', 'num_ext_media',
#        'text', 'is_verified', 'longitude', 'latitude'],
#       dtype='object')

# %%
df.dtypes
# Out:
# user_name              object
# num_retweets            int64
# num_likes               int64
# lang                   object
# num_user_followers      int64
# num_user_friends        int64
# num_ext_hashtags        int64
# num_ext_urls            int64
# num_ext_media           int64
# text                   object
# is_verified            object
# longitude             float64
# latitude              float64
# dtype: object

# %%
cnt
# Out:
# 123

# %%
df.describe()
# Out:
#        num_retweets     num_likes  num_user_followers  num_user_friends  \
# count  10500.000000  10500.000000        1.050000e+04      10500.000000
# mean     655.819238      1.168095        5.808436e+03        634.710095
# std     1282.876843     10.243694        1.201445e+05       1930.947001
# min        0.000000      0.000000        0.000000e+00          0.000000
# 25%        1.000000      0.000000        1.900000e+01         40.000000
# 50%       13.000000      0.000000        1.010000e+02        155.000000
# 75%      205.000000      0.000000        5.362500e+02        548.250000
# max     3456.000000    670.000000        7.846488e+06      82600.000000
#
#        num_ext_hashtags  num_ext_urls  num_ext_media   longitude    latitude
# count      10500.000000  10500.000000   10500.000000  123.000000  123.000000
# mean           0.979619      0.204762       0.113143   74.592504   22.917072
# std            1.070771      0.418380       0.316782   20.845186    5.699447
# min            0.000000      0.000000       0.000000  -84.820309    6.622513
# 25%            0.000000      0.000000       0.000000   72.744840   20.080191
# 50%            1.000000      0.000000       0.000000   77.000000   23.005830
# 75%            1.000000      0.000000       0.000000   80.214405   25.852856
# max           10.000000      3.000000       1.000000   92.325090   44.160540

# %%
df["num_retweets"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           0
# 1           0
# 2          47
# 3          14
# 4           0
#          ...
# 10495      33
# 10496      22
# 10497    3456
# 10498       0
# 10499    3456
# Name: num_retweets, Length: 10500, dtype: int64>

# %%
df["lang"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        en
# 1        hi
# 2        hi
# 3        en
# 4        hi
#          ..
# 10495    en
# 10496    hi
# 10497    en
# 10498    en
# 10499    en
# Name: lang, Length: 10500, dtype: object>

# %%
df.corr()
# Out:
#                     num_retweets  num_likes  num_user_followers  \
# num_retweets            1.000000  -0.056754           -0.022421
# num_likes              -0.056754   1.000000            0.214843
# num_user_followers     -0.022421   0.214843            1.000000
# num_user_friends       -0.113248  -0.003896            0.022322
# num_ext_hashtags        0.025426  -0.020572           -0.005334
# num_ext_urls           -0.249602   0.154204            0.065918
# num_ext_media          -0.176193   0.017473           -0.009840
# longitude               0.013351  -0.175504           -0.001794
# latitude                0.084552   0.057008           -0.031984
#
#                     num_user_friends  num_ext_hashtags  num_ext_urls  \
# num_retweets               -0.113248          0.025426     -0.249602
# num_likes                  -0.003896         -0.020572      0.154204
# num_user_followers          0.022322         -0.005334      0.065918
# num_user_friends            1.000000         -0.056368     -0.025254
# num_ext_hashtags           -0.056368          1.000000      0.016120
# num_ext_urls               -0.025254          0.016120      1.000000
# num_ext_media               0.042014          0.203638     -0.171225
# longitude                   0.090867          0.002644     -0.012629
# latitude                   -0.124947         -0.128955      0.054210
#
#                     num_ext_media  longitude  latitude
# num_retweets            -0.176193   0.013351  0.084552
# num_likes                0.017473  -0.175504  0.057008
# num_user_followers      -0.009840  -0.001794 -0.031984
# num_user_friends         0.042014   0.090867 -0.124947
# num_ext_hashtags         0.203638   0.002644 -0.128955
# num_ext_urls            -0.171225  -0.012629  0.054210
# num_ext_media            1.000000   0.012049 -0.097763
# longitude                0.012049   1.000000 -0.318445
# latitude                -0.097763  -0.318445  1.000000

# %%
for i in df.columns:
    print("Number of unique values for {} is {}".format(i,len(df[i].unique())))
# Out:
# Number of unique values for user_name is 8094
# Number of unique values for num_retweets is 94
# Number of unique values for num_likes is 74
# Number of unique values for lang is 23
# Number of unique values for num_user_followers is 2219
# Number of unique values for num_user_friends is 1910
# Number of unique values for num_ext_hashtags is 11
# Number of unique values for num_ext_urls is 4
# Number of unique values for num_ext_media is 2
# Number of unique values for text is 4029
# Number of unique values for is_verified is 2
# Number of unique values for longitude is 84
# Number of unique values for latitude is 84

# %%
df['lang'].unique()
# Out:
# array(['en', 'hi', 'und', 'gu', 'te', 'mr', 'ml', 'bn', 'ta', 'cy', 'es',
#        'kn', 'ht', 'in', 'it', 'et', 'lv', 'pa', 'fr', 'tl', 'pt', 'is',
#        'ja'], dtype=object)

# %%
df['num_ext_urls'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
df['lang'].value_counts()
# Out:
# en     7209
# hi     1698
# und    1188
# mr      110
# in       71
# te       54
# ta       54
# kn       45
# gu       17
# bn       15
# et        8
# cy        6
# ht        5
# es        4
# tl        3
# pt        3
# it        2
# is        2
# ml        2
# fr        1
# lv        1
# pa        1
# ja        1
# Name: lang, dtype: int64

# %%
df[df['lang']=='es']
# Out:
#                   user_name  num_retweets  num_likes lang  num_user_followers  \
# 468   Siddharth Sakpal 🇪🇺🇪🇺             0          1   es                 755
# 803             /سعد/ /ಸಾದ್             0          1   es                 222
# 1206              R Nithesh             0          0   es                  51
# 1293                  Aarti             0          0   es                  10
#
#       num_user_friends  num_ext_hashtags  num_ext_urls  num_ext_media  \
# 468                591                 2             0              1
# 803                231                 1             0              0
# 1206              1014                 2             1              0
# 1293                16                 1             1              0
#
#                                                    text   is_verified  \
# 468   = extra 2ab #NationalMathematicsDay\n#नॅशनलमॅथ...  not_verified
# 803           2 extra _AB 😜😜\n\n#NationalMathematicsDay  not_verified
# 1206  @officialparleg X = 16 ; Y = 30 ; Z = 7.\n\n16...  not_verified
# 1293  @officialparleg x = 16 y = 30 z = 7\n#ContestA...  not_verified
#
#       longitude  latitude
# 468         NaN       NaN
# 803         NaN       NaN
# 1206        NaN       NaN
# 1293        NaN       NaN

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['longitude'], y=df['latitude'])
plt.show()

from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(40, 30)), marker='o', color='red', markersize=15);

# %% [markdown]
# ## Do we get some useful correlations in the numerical fields ?

# %%
df.corr()
# Out:
#                     num_retweets  num_likes  num_user_followers  \
# num_retweets            1.000000  -0.056754           -0.022421
# num_likes              -0.056754   1.000000            0.214843
# num_user_followers     -0.022421   0.214843            1.000000
# num_user_friends       -0.113248  -0.003896            0.022322
# num_ext_hashtags        0.025426  -0.020572           -0.005334
# num_ext_urls           -0.249602   0.154204            0.065918
# num_ext_media          -0.176193   0.017473           -0.009840
# longitude               0.013351  -0.175504           -0.001794
# latitude                0.084552   0.057008           -0.031984
#
#                     num_user_friends  num_ext_hashtags  num_ext_urls  \
# num_retweets               -0.113248          0.025426     -0.249602
# num_likes                  -0.003896         -0.020572      0.154204
# num_user_followers          0.022322         -0.005334      0.065918
# num_user_friends            1.000000         -0.056368     -0.025254
# num_ext_hashtags           -0.056368          1.000000      0.016120
# num_ext_urls               -0.025254          0.016120      1.000000
# num_ext_media               0.042014          0.203638     -0.171225
# longitude                   0.090867          0.002644     -0.012629
# latitude                   -0.124947         -0.128955      0.054210
#
#                     num_ext_media  longitude  latitude
# num_retweets            -0.176193   0.013351  0.084552
# num_likes                0.017473  -0.175504  0.057008
# num_user_followers      -0.009840  -0.001794 -0.031984
# num_user_friends         0.042014   0.090867 -0.124947
# num_ext_hashtags         0.203638   0.002644 -0.128955
# num_ext_urls            -0.171225  -0.012629  0.054210
# num_ext_media            1.000000   0.012049 -0.097763
# longitude                0.012049   1.000000 -0.318445
# latitude                -0.097763  -0.318445  1.000000

# %% [markdown]
# ### Seeing the number of unique values

# %%
for i in df.columns:
    print("Number of unique values for {} is {}".format(i,len(df[i].unique())))
# Out:
# Number of unique values for user_name is 8094
# Number of unique values for num_retweets is 94
# Number of unique values for num_likes is 74
# Number of unique values for lang is 23
# Number of unique values for num_user_followers is 2219
# Number of unique values for num_user_friends is 1910
# Number of unique values for num_ext_hashtags is 11
# Number of unique values for num_ext_urls is 4
# Number of unique values for num_ext_media is 2
# Number of unique values for text is 4029
# Number of unique values for is_verified is 2
# Number of unique values for longitude is 84
# Number of unique values for latitude is 84
# Number of unique values for geometry is 84

# %% [markdown]
# ### A brief overview of dataset

# %%
df.describe()
# Out:
#        num_retweets     num_likes  num_user_followers  num_user_friends  \
# count  10500.000000  10500.000000        1.050000e+04      10500.000000
# mean     655.819238      1.168095        5.808436e+03        634.710095
# std     1282.876843     10.243694        1.201445e+05       1930.947001
# min        0.000000      0.000000        0.000000e+00          0.000000
# 25%        1.000000      0.000000        1.900000e+01         40.000000
# 50%       13.000000      0.000000        1.010000e+02        155.000000
# 75%      205.000000      0.000000        5.362500e+02        548.250000
# max     3456.000000    670.000000        7.846488e+06      82600.000000
#
#        num_ext_hashtags  num_ext_urls  num_ext_media   longitude    latitude
# count      10500.000000  10500.000000   10500.000000  123.000000  123.000000
# mean           0.979619      0.204762       0.113143   74.592504   22.917072
# std            1.070771      0.418380       0.316782   20.845186    5.699447
# min            0.000000      0.000000       0.000000  -84.820309    6.622513
# 25%            0.000000      0.000000       0.000000   72.744840   20.080191
# 50%            1.000000      0.000000       0.000000   77.000000   23.005830
# 75%            1.000000      0.000000       0.000000   80.214405   25.852856
# max           10.000000      3.000000       1.000000   92.325090   44.160540

# %%
#The purpose of using plt.figure() is to create a figure object.
fig = plt.figure(figsize=(15,4))
sns.countplot(x="num_ext_hashtags", data=df)

# %%
# look at miles overall distribution
fig = plt.figure(figsize=(15,7))
ax = fig.gca()
str2="num_user_followers"
sns.distplot(df[str2],kde=False,bins=1000)
plt.xlabel('Miles',fontsize=14,fontweight="bold")
plt.axvline(df[str2].median(),lw=3,ls='dotted',
            color='red',label='Median kms:'+'{0:.0f}'.format(np.median(df[str2])))
plt.axvline(df[str2].mean(),lw=3,ls='dashed',
            color='black',label='Mean kms:'+'{0:.0f}'.format(np.mean(df[str2])))
plt.title('Kms driven distribution over all Listings',fontsize=14,fontweight="bold")
plt.legend(loc='upper right',fontsize=16)
plt.xlim(-1000,1000)
plt.xlim(-1000,1000)

plt.show()

# %%
# look at miles by year boxplot
fig = plt.figure(figsize=(14,8))
ax = fig.gca()
sns.boxplot(x='num_likes',y='is_verified',data=df,orient='h')
plt.xlabel('Kms',fontsize=14,fontweight="bold")
ax.set_yticklabels(sorted(df["is_verified"].unique()))
plt.ylabel('Model Year',fontsize=14,fontweight="bold")
plt.title('Distribution of Kms per Model Year',fontsize=18,fontweight="bold")
plt.xlim(-5000,350000)
plt.show()

# %%
# look at price distribution
fig = plt.figure(figsize=(16,5))
ax = fig.gca()
col=df['num_user_followers']
sns.distplot(col,kde=False,bins=1000)
plt.xlabel('Price(in lakhs (Rs))',fontsize=14,fontweight="bold")
plt.axvline(col.mean(),lw=3,ls='dashdot',
            color='black',label='Mean price:'+'{0:.0f}'.format(np.mean(col)))
plt.axvline(col.median(),lw=3,ls='dashed',
            color='red',label='Median price:'+'{0:.0f}'.format(np.median(col)))
plt.title('Distribution of Resale Prices over all Listings',fontsize=18,fontweight="bold")
plt.legend(loc='upper right',fontsize=16)
plt.xlim(-1,90000)
plt.show()

# %%
sns.displot(df, x="num_user_followers", binwidth=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-373-08375a93e2f6> in <module>
# ----> 1 sns.displot(df, x="num_user_followers", binwidth=3)
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
fig = plt.figure(figsize=(16,5))
col=distplot
sns.distplot(col,bins=10000,kde=False,hist_kws={'log':True})
plt.xlim(-1,90000)

plt.show()

# %% [markdown]
# * Possible stuff:
# * Number of followers
# * Verified users
# * Has a photograph
# * Language data
# * Most used words in the text
# * URL there
# * Mention other hashtags also
# * Word cloud here also
# * Hashtag wordcloud + freq {others}

# %%
df.columns
# Out:
# Index(['user_name', 'num_retweets', 'num_likes', 'lang', 'num_user_followers',
#        'num_user_friends', 'num_ext_hashtags', 'num_ext_urls', 'num_ext_media',
#        'text', 'is_verified', 'longitude', 'latitude', 'geometry'],
#       dtype='object')

# %% [markdown]
# # Number of followers trend

# %%
fig = plt.figure(figsize=(16,5))
sns.kdeplot(df['num_user_followers'],shade=True,color="b",legend=False)

# %%
fig = plt.figure(figsize=(12,10))
sns.kdeplot(df.loc[(df["is_verified"]=="verified")]['num_user_followers'],shade=True,color="b",legend=False)
sns.kdeplot(df.loc[(df["is_verified"]=="not_verified")]['num_user_followers'],shade=True,color='r',legend=False)
df.groupby("is_verified")["num_user_followers"].describe()
# Out:
#                 count           mean            std    min     25%      50%  \
# is_verified
# not_verified  10309.0    1176.021632    7030.663970    0.0    18.0     97.0
# verified        191.0  255837.554974  854951.020319  591.0  6114.0  21603.0
#
#                   75%        max
# is_verified
# not_verified    480.0   351581.0
# verified      93382.5  7846488.0

# %% [markdown]
# # Number of likes trend

# %%
fig = plt.figure(figsize=(16,5))
sns.kdeplot(df['num_likes'],shade=True,color="b",legend=False,bw=1.5)

# %%
fig = plt.figure(figsize=(20,10))
sns.kdeplot(df.loc[(df["is_verified"]=="verified")]['num_likes'],shade=True,color="b",legend=False,bw=1.5)
sns.kdeplot(df.loc[(df["is_verified"]=="not_verified")]['num_likes'],shade=True,color='r',legend=False,bw=1.5)
df.groupby("is_verified")["num_likes"].describe()
# Out:
#                 count       mean        std  min  25%  50%   75%    max
# is_verified
# not_verified  10309.0   0.800757   8.626609  0.0  0.0  0.0   0.0  670.0
# verified        191.0  20.994764  36.857977  0.0  1.0  6.0  21.5  198.0

# %%
fig = plt.figure(figsize=(20,6))
sns.boxplot(x="num_likes",y="is_verified",data=df,linewidth=2.5,palette="Set2")

# %% [markdown]
# # Number of retweets trend

# %%
fig = plt.figure(figsize=(16,5))
sns.kdeplot(df['num_retweets'],shade=True,color="b",legend=False,bw=1.5)

# %%
fig = plt.figure(figsize=(20,10))
sns.kdeplot(df.loc[(df["is_verified"]=="verified")]['num_retweets'],shade=True,color="b",legend=False,bw=1.5)
sns.kdeplot(df.loc[(df["is_verified"]=="not_verified")]['num_retweets'],shade=True,color='r',legend=False,bw=1.5)
df.groupby("is_verified")["num_retweets"].describe()
# Out:
#                 count        mean          std  min  25%   50%    75%     max
# is_verified
# not_verified  10309.0  667.336114  1291.433412  0.0  1.0  14.0  205.0  3456.0
# verified        191.0   34.209424   252.524846  0.0  1.0   3.0   12.5  3455.0

# %%
sns.heatmap(df.corr())
#sns.pairplot(df, hue="gender", markers=["o", "x"])

# %%
sns.pairplot(df, hue="is_verified", markers=["o", "x"], diag_kws={'bw': 0.2})

# %%
fig = plt.figure(figsize=(15,4))
sns.countplot(x="num_likes", data=df)

# %%
b

# %%
fig = plt.figure(figsize=(25,16))
sns.lmplot('num_likes','num_user_followers',data=df,order=1,hue="is_verified",scatter=True,markers=["x", "o"],height=10, aspect=1.3)

# %% [markdown]
# # Number of likes and retweet trend

# %% [markdown]
# # More number of verified users

# %% [markdown]
# # Likes vs followers trends

# %% [markdown]
# a

# %% [markdown]
# a

# %% [markdown]
# a

# %% [markdown]
# # Number of connected components

# %%
user_id_list
# Out:
# [186688647,
#  1263783748493074432,
#  976868343914385414,
#  1158118831857926144,
#  825343251347550208,
#  912671279093661696,
#  1262686725052289024,
#  1082916096175304704,
#  1091246625719087105,
#  3108117042,
#  1333149297102110720,
#  65898016,
#  1010472346996506624,
#  739360603429429248,
#  746587232123879424,
#  298965936,
#  1260461933096042496,
#  723139844516388864,
#  3235175558,
#  1341289637302550528,
#  762699048277143552,
#  1151536892388638720,
#  4379858834,
#  1333730689729007623,
#  490550638,
#  1035143935046299648,
#  1260461933096042496,
#  1316560548541022210,
#  836803806155390976,
#  1096301815518289920,
#  717309481915260928,
#  461084283,
#  1330430679910387713,
#  770183342620827648,
#  1259815801437085701,
#  1332566879156662275,
#  1294627633750138886,
#  1332566879156662275,
#  1215880546472980480,
#  1329769091603697664,
#  1208407177121206273,
#  1150077062113157120,
#  1282995002566569984,
#  815602261544017920,
#  44207288,
#  1332566879156662275,
#  1303558619770712064,
#  1332566879156662275,
#  726844259148550144,
#  1332566879156662275,
#  838289631238029312,
#  1190182006065258501,
#  1332566879156662275,
#  200176122,
#  834418748,
#  1332566879156662275,
#  1293295586947616770,
#  1332566879156662275,
#  1107955565383151616,
#  922390106903797760,
#  1662608774,
#  975352833569468417,
#  171159782,
#  773618666,
#  1173444241441218561,
#  1161248035394867202,
#  3251637835,
#  2810422716,
#  4385909953,
#  1335786068,
#  1029978464470937600,
#  799651612201537536,
#  1340237651341819906,
#  3177388206,
#  1340155797448388608,
#  1335114888859983872,
#  1262686725052289024,
#  1109382804687781888,
#  315888743,
#  2293519094,
#  1167889267,
#  3251637835,
#  993804218774540294,
#  3177388206,
#  936818810425716737,
#  761508052667277312,
#  1173444241441218561,
#  1297758373111164929,
#  822640898819428353,
#  1211574570945138688,
#  1244638573728587779,
#  307830107,
#  759331920,
#  124470435,
#  906914776906735617,
#  114734728,
#  1300733175866376192,
#  1206052729132466177,
#  2553353635,
#  1116154907583606784,
#  1300733175866376192,
#  828597772601352192,
#  1259085824727166977,
#  1334858914358149120,
#  915205826939199488,
#  1023934413636173824,
#  817585241237823489,
#  1203368538573901825,
#  2588968255,
#  761508052667277312,
#  1023934413636173824,
#  459942649,
#  3253945808,
#  1330189260390019075,
#  1313245996218871808,
#  925963769804554240,
#  1190910398741921792,
#  19338611,
#  1173444241441218561,
#  941309260901822466,
#  2827821866,
#  1247497236134559745,
#  1330189260390019075,
#  370048167,
#  421595024,
#  2827821866,
#  1330189260390019075,
#  2827821866,
#  1212672140014546945,
#  1330189260390019075,
#  421595024,
#  141080665,
#  1249727934413197314,
#  1109382804687781888,
#  1330189260390019075,
#  1104626330685960192,
#  2827821866,
#  1157575715178479616,
#  1330189260390019075,
#  1330189260390019075,
#  1330189260390019075,
#  1341009472043569154,
#  1310407732290150400,
#  1261706731219873795,
#  1241287140518121472,
#  1289944398235488256,
#  147527484,
#  303772272,
#  2413729134,
#  1330189260390019075,
#  1208728452876165120,
#  764747628726759426,
#  1126913833098866688,
#  1278213801708380160,
#  1320587532132773888,
#  1241287140518121472,
#  1330189260390019075,
#  2700778112,
#  1201339620450979841,
#  2313189042,
#  1267023817529913344,
#  760422993776508929,
#  131607714,
#  1173444241441218561,
#  1273242977826074626,
#  1305163427246039042,
#  764747628726759426,
#  805709372500287488,
#  1224732554550366209,
#  399928968,
#  1258057295478484992,
#  1335566564326699014,
#  1290943334052016128,
#  1317695827700195328,
#  2343682555,
#  1554943507,
#  1029260118221701126,
#  9708142,
#  3312182599,
#  895554989149396993,
#  1327903597586124800,
#  1300798826505142278,
#  787039267,
#  2438126664,
#  1231983957694009345,
#  3312182599,
#  43508695,
#  1259141078860681217,
#  1131975023483338752,
#  96183118,
#  3445524312,
#  1290965887676104709,
#  344806141,
#  2734566654,
#  344030014,
#  3312253848,
#  864503579578695681,
#  1272138546975895554,
#  767007424335130625,
#  786530710936956928,
#  1335786068,
#  1270912234978336770,
#  934003727559569409,
#  1518596924,
#  1146300388645060608,
#  1332576542191284224,
#  1263977155,
#  1341265288013049856,
#  1271256303139205123,
#  891729970443075584,
#  30250753,
#  1240625152812920833,
#  1300799145725181956,
#  711607213412888576,
#  1279347899894165509,
#  1148878423584100352,
#  1253387093700759555,
#  1339418298211921921,
#  835143170635673600,
#  1332273714168094720,
#  1164351015912534016,
#  1103977104092397571,
#  987593923936731141,
#  1238113292318580737,
#  972165507666202624,
#  1103977104092397571,
#  2934735584,
#  982082920071524352,
#  4286938938,
#  1337048670315962369,
#  1271018141351473157,
#  3312253848,
#  1272138546975895554,
#  1335113051691839489,
#  1336654314052325380,
#  2531254100,
#  47332714,
#  1336654314052325380,
#  946641920222117888,
#  1182101929041645570,
#  1336654314052325380,
#  1161980940916154368,
#  1332273714168094720,
#  465573729,
#  342797634,
#  1332576542191284224,
#  1339232123333406722,
#  1171319572189741057,
#  888636269609103360,
#  1244939967668740101,
#  1156985745329946629,
#  363162881,
#  1336654314052325380,
#  1156133205809876998,
#  1237035624755941378,
#  1339418298211921921,
#  782591292777885696,
#  1335786068,
#  876072970023612416,
#  1240625152812920833,
#  1306982127154597889,
#  1025624000662130694,
#  1264106464718622721,
#  1260594190267723776,
#  1336654314052325380,
#  3259782206,
#  1218250255356944384,
#  1282616713796698112,
#  1156826149646786560,
#  1261543164105699329,
#  2583858967,
#  1167037307200794625,
#  168764720,
#  1146249629509439488,
#  1156826149646786560,
#  2389445124,
#  716973659320004609,
#  1339278983616024577,
#  876072970023612416,
#  840928981788454916,
#  1263511404184813573,
#  927031196,
#  1562847896,
#  1283441940223033344,
#  3259782206,
#  1271377216027258881,
#  799913082931843072,
#  982469128744189953,
#  1024274414680981504,
#  1234018568158662657,
#  1249235172555292672,
#  40017565,
#  906492783220760577,
#  1285203517003554822,
#  424809431,
#  982469128744189953,
#  906912620371783680,
#  1314155084847091717,
#  1249235172555292672,
#  1232562737873448962,
#  1234018568158662657,
#  849167156394819584,
#  979682565698174976,
#  3038992543,
#  1309417883294818304,
#  3259782206,
#  392860394,
#  1234018568158662657,
#  1301343403477590017,
#  155135748,
#  1234018568158662657,
#  4477841427,
#  1285203517003554822,
#  999520676745658368,
#  129467307,
#  1217167315688509441,
#  796410214706774023,
#  1278603036881899521,
#  757149111233581059,
#  787351795165114368,
#  1149197163420774400,
#  860086112118857728,
#  948992130,
#  1240625152812920833,
#  3259782206,
#  159498467,
#  1234018568158662657,
#  1246358609425920001,
#  1234018568158662657,
#  1282322286452899841,
#  17153195,
#  1149197163420774400,
#  362389696,
#  1149197163420774400,
#  923476421070135296,
#  974276758638755841,
#  52100788,
#  1327903597586124800,
#  1329719863414190080,
#  1272041037368713216,
#  758515939965034497,
#  3259782206,
#  1267764489539158022,
#  1213120167607070721,
#  882861758217691136,
#  1217167315688509441,
#  777201371108020224,
#  863345255919132672,
#  1213120167607070721,
#  1107562676660654081,
#  1300799145725181956,
#  1939842493,
#  1741938662,
#  1240625152812920833,
#  1065243634927263744,
#  1272041037368713216,
#  1301343403477590017,
#  1243027573497450496,
#  1177835042451550208,
#  875568768176373761,
#  797398048640933888,
#  1462802419,
#  1093549329770377216,
#  1332204152009605121,
#  2292675078,
#  1148847767210487808,
#  1300799145725181956,
#  797398048640933888,
#  835300353377726464,
#  1331857526988566528,
#  1134339124347826176,
#  1243031887276171265,
#  1220259364688166913,
#  1236699103108587523,
#  1283439346897481730,
#  1301343403477590017,
#  1298078933070409728,
#  168122789,
#  80818570,
#  2903289272,
#  1259125455581413377,
#  1268112262302138370,
#  919126544110333953,
#  3371986344,
#  1272428314678792192,
#  1173233795803361281,
#  4036699340,
#  1059257512384520192,
#  1243027573497450496,
#  919126544110333953,
#  215919114,
#  3235939718,
#  716973659320004609,
#  1267016939718705153,
#  1217343013023694848,
#  260636255,
#  89154789,
#  934781972894793728,
#  1267111403455840256,
#  1242093826782539776,
#  825591728451186688,
#  1357570849,
#  1217167315688509441,
#  1217343013023694848,
#  856860164611334144,
#  3305829824,
#  1217167315688509441,
#  227685123,
#  1513865904,
#  1336148442683383814,
#  140382046,
#  1300779913448845314,
#  1132116614407643136,
#  1245348919728431104,
#  1336148442683383814,
#  246253637,
#  1044330227881533440,
#  1103583430900572160,
#  1131492998225596416,
#  1185853111249731584,
#  948992130,
#  1137366662288556037,
#  2939075708,
#  1073687646839271424,
#  1127630178644054018,
#  1308656884610670599,
#  1103583430900572160,
#  2268595214,
#  104095612,
#  1281519386285596673,
#  1308656884610670599,
#  1185853111249731584,
#  1044330227881533440,
#  856860164611334144,
#  1174234445429317633,
#  3665895553,
#  815511180,
#  2486092061,
#  2488510225,
#  1206808482533429248,
#  2965853779,
#  1329141566724718592,
#  1027285564578394112,
#  1281519386285596673,
#  1052127112885399552,
#  1341272296900575232,
#  1026477393974718474,
#  1038326970092740609,
#  2748592068,
#  948992130,
#  1237367530303324161,
#  875830081,
#  1171677214036807680,
#  948992130,
#  4416969494,
#  1100569484824375301,
#  1038326970092740609,
#  141197507,
#  900337632093159424,
#  864124403759689734,
#  1225727048,
#  996231742968090624,
#  1226472328764231681,
#  875830081,
#  1185634418041294848,
#  948992130,
#  707796950196883457,
#  1331811648709922816,
#  1286937680220049410,
#  1046649436821061632,
#  71189173,
#  124375542,
#  1147855874028785665,
#  1208996290626912256,
#  1114082494008020995,
#  1175697188124413952,
#  763477106282074113,
#  43508695,
#  1271445605143867392,
#  1309330227173220353,
#  1290209176057049088,
#  1301492266188419072,
#  1298594253405265920,
#  1175697188124413952,
#  3286638607,
#  1243924387704823808,
#  2879608795,
#  1297801763739770880,
#  1119577826011729922,
#  948992130,
#  895012699448397824,
#  1024690782811303937,
#  836578017048580097,
#  721673240,
#  2856762817,
#  1297801763739770880,
#  1305443454969757697,
#  1216955911639449600,
#  1655899814,
#  2616893581,
#  1332215060496695296,
#  1260594190267723776,
#  1151367151086735360,
#  3665895553,
#  3269217056,
#  2658669696,
#  1311190729897644032,
#  862550077486845952,
#  1260186516745142272,
#  1203009675911778305,
#  1260186516745142272,
#  1241643795382300672,
#  856860164611334144,
#  1260186516745142272,
#  719563896583888896,
#  1326908559372771330,
#  1260186516745142272,
#  4749548701,
#  1335255946893750272,
#  1260186516745142272,
#  4379858834,
#  1276103554407657472,
#  1260186516745142272,
#  3308460655,
#  1260186516745142272,
#  1236674619391631360,
#  1093169108324110336,
#  1133298328324599808,
#  284575061,
#  2261031134,
#  1260186516745142272,
#  2780698736,
#  1234343298434621445,
#  767238971667652608,
#  3665895553,
#  1677743432,
#  1109145561360412672,
#  282589591,
#  1275802952897187841,
#  1201897753460248576,
#  852328268032245762,
#  2395447554,
#  2780698736,
#  1330097208578945027,
#  372754427,
#  1282393737235099651,
#  37634528,
#  980416278408998912,
#  818686471653785601,
#  1302193672205656065,
#  965633329096724486,
#  1335117685642862592,
#  1210399030565408770,
#  473654942,
#  555010847,
#  1297788399101734912,
#  1276811260684693504,
#  1590405854,
#  822281860491472897,
#  44089387,
#  1239031304382861317,
#  3288379706,
#  1024690782811303937,
#  1322179373814870029,
#  1650028064,
#  1590405854,
#  1970410146,
#  1239552297421676576,
#  1190639572385841152,
#  1174892900598992897,
#  1340956208677568514,
#  1258079580788854784,
#  1322515364190846982,
#  916226097351553024,
#  1209784141513756673,
#  1114775330,
#  1300076975051034624,
#  717225013183717376,
#  1023846232278487041,
#  1225467985889906688,
#  1082557053640486912,
#  1256625876600418305,
#  784960830706184196,
#  905021510120648705,
#  2197120621,
#  1338754030592434176,
#  3251352692,
#  1289314350445076481,
#  90807966,
#  1273626790385180673,
#  2903289272,
#  1332271701523013632,
#  1039759933728645120,
#  1186207914886754305,
#  1278603036881899521,
#  1310440539653722113,
#  1590405854,
#  1044330227881533440,
#  726981136438558721,
#  1250834263173328896,
#  1073128841378492416,
#  2610760831,
#  1326033061356605440,
#  4771594249,
#  1273626790385180673,
#  916226097351553024,
#  1341283355967377409,
#  1195270984627916801,
#  1164235197501468673,
#  984693636032954368,
#  1110967140725592064,
#  212858578,
#  761355158978605057,
#  1143893760637407232,
#  18531351,
#  1336785544529920000,
#  1044150837675585536,
#  896770456341983233,
#  2903289272,
#  133013463,
#  2987237858,
#  3746054474,
#  1260199976518316033,
#  4902145820,
#  1286135674777657347,
#  1261279806592819200,
#  1093169108324110336,
#  1322381185130000384,
#  1246315866053947400,
#  1341283355967377409,
#  1038007423905062912,
#  1153970559178330112,
#  1272871617043951616,
#  1024302657861603328,
#  1330091175492116482,
#  999882050067877888,
#  1243569730612531200,
#  1245991093633609729,
#  2546517146,
#  1328992975150452736,
#  1004313252761776128,
#  863298195442368513,
#  896770456341983233,
#  63020100,
#  2854212666,
#  1267016939718705153,
#  2751507475,
#  899331169832927232,
#  3312941568,
#  905021510120648705,
#  710704451888291841,
#  718031036890750977,
#  4687789884,
#  1025673206277914624,
#  1446492452,
#  381596762,
#  1655797862,
#  1245021938830827520,
#  1339480228255596550,
#  1103367024468733953,
#  2921783995,
#  1138041638217953283,
#  1025673206277914624,
#  1072557885953998848,
#  2873087792,
#  1152827825298132993,
#  1159499148103544832,
#  1245021938830827520,
#  3741319636,
#  2589237367,
#  1270872204402503681,
#  2767487587,
#  1292148428508524544,
#  981122052135374848,
#  195085357,
#  1300649786475831296,
#  126230717,
#  1152827825298132993,
#  832619247520010246,
#  3052149560,
#  467311515,
#  979682565698174976,
#  1335459369345900550,
#  2472485690,
#  1305373642826473473,
#  859713707278032897,
#  126230717,
#  822859024416673792,
#  2854327913,
#  1241807383354945536,
#  1291768573862371328,
#  1340649535345807360,
#  1246840986531053568,
#  736867482825199616,
#  1117365829761478657,
#  ...]

# %%
list_set = set(user_id_list) 
# convert the set to the list 
user_id_list = (list(list_set))

# %%
def is_connected(num1,num2):
    a_headers = {
    'Authorization': 'Bearer {}'.format(access_token)
    }

    paramsa = {

        'source_id': num1,
        'target_id': num2,
        'source_screen_name':user_map[num1],
        'target_screen_name':user_map[num2]
        
        
    }
    import requests 
    from requests.auth import HTTPBasicAuth 
  
    print(paramsa)
    # https://developer.twitter.com/en/docs/twitter-api/v1/accounts-and-users/follow-search-get-users/api-reference/get-friendships-show
    url = 'https://api.twitter.com/1.1/friendships/lookup.json'  
    resp = requests.get(url, headers=a_headers, params=paramsa,auth = HTTPBasicAuth('anmolagarwal999', '5'))
    rel=resp.json()
    print(rel)
    if rel["source"]["following"]==True or rel["source"]["followed_by"]==True:
        return True
    if rel["target"]["following"]==True or rel["target"]["followed_by"]==True:
        return True
    return False

# %%
len(user_id_list)
# Out:
# 8276

# %%
adj={}
for i in range(0,len(user_id_list)):
    adj[user_id_list[i]]=[]
    
for i in range(0,len(user_id_list)):
    num1=user_id_list[i]    
    for j in range(i+1,len(user_id_list)):
        num2=user_id_list[j]
        if is_connected(num1,num2)==True:
            adj[num1].append(num2)
            adj[num2].append(num1)
# Out:
# {'source_id': 1158118831857926144, 'target_id': 1010472346996506624, 'source_screen_name': '🌸 एकता शुक्ला 🌸', 'target_screen_name': 'NAMASTE EXO🙏🏼 || MINSEOK IS BACK || KAI 开 ||'}
# {'errors': [{'code': 215, 'message': 'Bad Authentication data.'}]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-384-385aedca313b> in <module>
#       7     for j in range(i+1,len(user_id_list)):
#       8         num2=user_id_list[j]
# ----> 9         if is_connected(num1,num2)==True:
#      10             adj[num1].append(num2)
#      11             adj[num2].append(num1)
#
# <ipython-input-382-7fec75efc5a6> in is_connected(num1, num2)
#      22     rel=resp.json()
#      23     print(rel)
# ---> 24     if rel["source"]["following"]==True or rel["source"]["followed_by"]==True:
#      25         return True
#      26     if rel["target"]["following"]==True or rel["target"]["followed_by"]==True:
#
# KeyError: 'source'

# %%
""
